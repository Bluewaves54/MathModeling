# %%
# Imports modules
import numpy as np
import tensorflow as tf
import pandas as pd
from matplotlib import pyplot as plt

# %%
#Loads dataset and seperates into X and Y
dataset = pd.read_csv('../dataset/temp.csv', on_bad_lines='skip')
X = dataset.Year
Y = dataset['Degrees C']

# %%
plt.plot(X, Y)
plt.show()
