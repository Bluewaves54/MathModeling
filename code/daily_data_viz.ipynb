# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('../data/co2-ppm-daily_csv.csv')
inter_data = pd.read_csv('../data/interpolated_data.csv')

# %%
plt.plot(data.value)
plt.plot(inter_data.PPM)
